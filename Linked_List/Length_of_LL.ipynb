# %%
from Common import Node,take_input_better,print_LL

def lengthOfLL(head):
    temp = head
    ans = 0

    while(temp != None):
        temp = temp.next
        ans = ans + 1

    return ans

# headOfLL = take_input_better()
# length = lengthOfLL(headOfLL)
# print(length)

def lengthOfLLRecursive(head):
    if(head == None):
        return 0

    recursionAnswer = lengthOfLLRecursive(head.next)

    return 1 + recursionAnswer

lenght = lengthOfLLRecursive(headOfLL)
print(length)
# Out:
# 3
