# %%
from Common import *

def reverse_LL(head):
    print_LL(head)
    if(head == None or head.next == None):
        return head

    smallLLHead = reverse_LL(head.next)

    temp = smallLLHead
    while(temp.next is not None):
        temp = temp.next

    temp.next = head
    head.next = None

    return smallLLHead

# head = CreateLLFromList([1,2,3,4,5])
# head = reverse_LL(head)
# print_LL(head)

def reverse_LL_Better(head):
    if(head == None or head.next == None):
        return head

    smallLLHead = reverse_LL_Better(head.next)

    tailOfReversedList = head.next
    tailOfReversedList.next = head
    head.next = None

    return smallLLHead

# head = CreateLLFromList([1,2,3,4,5])
# print_LL(head)
# head = reverse_LL_Better(head)
# print_LL(head)

def reverse_LL_iteration(head):
    if(head == None or head.next == None):
        return head

    prev = None
    current = head

    while current is not None:
        next_node = current.next
        current.next = prev
        prev = current
        current = next_node

    return prev

head = reverse_LL_iteration(CreateLLFromList([1,2,3,4,5]))
print_LL(head)
# Out:
# 5
# 4
# 3
# 2
# 1
